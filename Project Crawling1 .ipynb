# %%
import tweepy
from tweepy import OAuthHandler, Stream, StreamListener 
import datetime

consumer_key="9gnPNqHJCTIRPWOeIVHoWvXxj"
consumer_secret="HIxLMOrSFFM44isSkR3J00Df2qBb2KbpaTMiLVoEjHZ1P3XqYv"
access_token="248112786-UPC1lD7fIKOdfxn0ZcwymNbZWyP68JOHSO5ce9oS"
access_token_secret="X2qIeYYZ7UclfGalhCh1bd4xGQuStxHENP2V3U74WyQSb"
auth = OAuthHandler(consumer_key, consumer_secret,)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline()
for tweet in tweets:
    print (tweet.text)
# Out:
# RT @mrssiwon407: @askmenfess Ls by @fermendkis https://t.co/fF6KncpdXb
# tapi ini juga bisa dibaca sebagai gagalnya para aktivis menjelaskan apa itu aktivisme dan politik kepada orang-oran… https://t.co/QDXWG5mOu0
# semua gara-gara promo yang gokil ini nih:
# https://t.co/ontv65Ip5l
# Islam began as something strange and will revert to being strange as it began, so give glad tidings to the strangers [Muslim]
# Nyari perhatian aja susah, palagi kepastian.
#
# Sadar diri aja ya, capek sendiri ntar.
# senang banget rasanya, setelah sekian lama nggak makan berdua dengan 'seseorang' akhirnya malam ini kesempatan itu… https://t.co/SYQKlE6x9x
# 😊 https://t.co/NIlCH0gy9V
# Purwokerto tanggal 3 dan Tegal tanggal 4 bulan november ya. Catat dulu saja. Sampai ketemu.
# RT @andhikaapuspita: “Mau ganteng atau tidak, kalau hatinya tidak satu frekuensi, bagaimana?” -BJ. Habibie https://t.co/kzHtFnH4Hd
# RT @Putrisep12: Lak mendo jo suwe suwe https://t.co/PJMqMlaqnK
# ...

# %%
user_tweets = api.user_timeline(screen_name='awkarin', count=200, tweet_mode="extended")
for tweet in user_tweets:
    print(tweet._json)
# Out:
# {'created_at': 'Sun Oct 27 05:56:04 +0000 2019', 'id': 1188333522529832961, 'id_str': '1188333522529832961', 'full_text': 'Btw yang menang sejuta rupiah tadi malam adalah......\n\n@n4maku ✨\n\nCongrats! Dm aku rek km ya ❤️ https://t.co/FdskdI2pi5', 'truncated': False, 'display_text_range': [0, 95], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'n4maku', 'name': 'Senja', 'id': 1099301458418098181, 'id_str': '1099301458418098181', 'indices': [55, 62]}], 'urls': [{'url': 'https://t.co/FdskdI2pi5', 'expanded_url': 'https://twitter.com/awkarin/status/1188095675235323904', 'display_url': 'twitter.com/awkarin/status…', 'indices': [96, 119]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2918748864, 'id_str': '2918748864', 'name': 'kari
# ...

# %%
the_list = []
tweet_awkarin = api.user_timeline(screen_name='awkarin', count=200, tweet_mode="extended")
start_date = datetime.datetime(2019,10,22, 00,00,00)
end_date = datetime.datetime(2019,10,23, 23,59,59)
for tweet in tweet_awkarin:
    the_list.append(tweet._json)

# %%
import pandas
myData = pandas.DataFrame(the_list)
myData
# Out:
#                          created_at                   id               id_str  \
# 0    Sun Oct 27 05:56:04 +0000 2019  1188333522529832961  1188333522529832961
# 1    Sun Oct 27 05:40:31 +0000 2019  1188329606903762944  1188329606903762944
# 2    Sun Oct 27 05:38:14 +0000 2019  1188329035954155520  1188329035954155520
# 3    Sun Oct 27 05:35:57 +0000 2019  1188328460281761792  1188328460281761792
# 4    Sun Oct 27 05:35:24 +0000 2019  1188328322242973697  1188328322242973697
# ..                              ...                  ...                  ...
# 195  Tue Oct 15 04:51:20 +0000 2019  1183968575419080704  1183968575419080704
# 196  Tue Oct 15 04:49:17 +0000 2019  1183968059742048256  1183968059742048256
# 197  Tue Oct 15 04:46:59 +0000 2019  1183967483096485888  1183967483096485888
# 198  Tue Oct 15 04:43:32 +0000 2019  1183966615576051712  1183966615576051712
# 199  Tue Oct 15 02:54:55 +0000 2019  1183939281695281153  1183939281695281153
#
# ...
